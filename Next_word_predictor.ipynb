# %%
faqs = """what is difference bw cv. And resume

The terms CV and Resume are often used interchangeably, but they are actually different.

Feature	Resume	CV (Curriculum Vitae)
Length	1–2 pages	2–10+ pages
Purpose	Job applications in industry	Academic, research, teaching positions
Content	Skills, projects, experience relevant to the job	Complete academic and professional history
Customization	Tailored for each job	Usually updated continuously, not heavily customized
Focus	Practical skills and achievements	Education, research, publications, certifications, conferences
Resume Example (for an AI/ML student like you)
Contact Information
Career Objective
Education
Technical Skills
Projects
Internships
Certifications (AZ-900, etc.)
Achievements
Extracurricular Activities

Typically 1 page for students and freshers.

CV Example
Contact Information
Education History
Research Experience
Publications
Conferences Attended
Teaching Experience
Awards
Certifications
Projects
Technical Skills
References

Can easily be 3–10+ pages.

For You

As a B.Tech AI/ML student looking for internships and placements, you should primarily create a Resume, not a CV.

Most companies hiring AI/ML interns, software engineers, and data scientists in industry expect a 1-page ATS-friendly resume. A CV is usually needed if you apply for:

Research internships
M.Tech/MS programs
PhD programs
Academic positions

For campus internships and placements at GLA University, focus on building a strong 1-page resume highlighting:

Python
Machine Learning
Deep Learning
Projects (Customer Churn Prediction, Diabetes Prediction, etc.)
Azure AZ-900 Certification
GitHub and Kaggle profiles
DSA progress

That will help you much more than maintaining a long CV at this stage.

For AI/ML roles, you do not need every DSA topic at the same depth as someone targeting hardcore competitive programming or low-level systems roles.

A practical DSA syllabus for AI/ML engineers would be:

Phase 1: Programming Foundations
Time Complexity (Big O)
Space Complexity
Recursion
Basic Math
Bit Manipulation (basics)
Phase 2: Arrays & Strings

These are used constantly in coding interviews.

Array Traversal
Prefix Sum
Sliding Window
Two Pointers
Hashing
String Manipulation

LeetCode focus:

Easy → Medium
Two Sum
Best Time to Buy and Sell Stock
Valid Anagram
Longest Substring Without Repeating Characters
Product of Array Except Self
Phase 3: Linked Lists
Singly Linked List
Doubly Linked List
Fast & Slow Pointers
Reverse Linked List
Cycle Detection
Phase 4: Stacks & Queues

Very common.

Stack
Queue
Deque
Monotonic Stack
Priority Queue (Heap)

Problems:

Valid Parentheses
Daily Temperatures
Next Greater Element
Kth Largest Element
Phase 5: Trees

Extremely important.

Binary Trees
BST
DFS
BFS
Tree Traversals
Lowest Common Ancestor

Problems:

Maximum Depth
Invert Tree
Diameter of Binary Tree
Path Sum
Phase 6: Heaps

Important for AI/data processing.

Min Heap
Max Heap
Heapify

Applications:

Top-K Problems
Recommendation Systems
Streaming Data
Phase 7: Binary Search

Used everywhere.

Binary Search
Search Space Problems
Lower Bound
Upper Bound
Phase 8: Graphs

Very important for modern AI.

Graph Representation
BFS
DFS
Topological Sort
Union Find
Shortest Path

Problems:

Number of Islands
Clone Graph
Course Schedule

Graphs are especially useful if you later study:

Knowledge Graphs
Graph Neural Networks (GNNs)
Recommendation Systems
Phase 9: Dynamic Programming

Most difficult topic.

1D DP
2D DP
Knapsack
LCS
LIS

Don't rush this topic.

Phase 10: Advanced Topics (Optional)
Trie
Segment Tree
Fenwick Tree
Advanced Graph Algorithms

For most AI/ML roles, these are less important.

If your goal is AI Engineer / ML Engineer

Priority order:

Arrays & Strings
Hashing
Sliding Window
Binary Search
Trees
Heaps
Graphs
DP
Linked Lists
Stack & Queue
The AI-specific CS topics that matter alongside DSA

Don't spend all your time on DSA. For AI jobs, also study:

Data Structures & Algorithms
Object-Oriented Programming
Database Management Systems (DBMS)
Operating Systems (OS)
Computer Networks (CN)
SQL
Python
Machine Learning
Deep Learning
PyTorch
NLP
Transformers
RAG
LLMs
MLOps

For someone in your position (AI/ML student aiming for internships), I'd suggest roughly:

40% AI/ML
40% DSA
20% CS fundamentals (OS, DBMS, CN, OOP)

That balance is usually stronger for AI internship interviews than focusing only on AI models.

I'm ahead how many percent students

No one can measure this precisely, but based on the information you've shared, I can give a rough estimate.

Compared with AI/ML students at a similar stage (second year of B.Tech):

Areas where you're ahead

✅ You already know Python, NumPy, Pandas, ML, DL basics, NLP, and deployment concepts.

✅ You have completed multiple projects and uploaded work to GitHub/Kaggle.

✅ You have an AI/ML-focused roadmap and actively study beyond your college syllabus.

✅ You have an industry certification (AZ-900).

✅ You're already thinking about PyTorch, Transformers, RAG, Agentic AI, and MLOps.

Areas where you still need growth

⚠️ No internship yet.

⚠️ DSA is still developing.

⚠️ Limited evidence of large production-grade projects.

⚠️ No research publications/open-source contributions mentioned.

⚠️ Interview preparation and CS fundamentals can be strengthened.

Rough estimate

Among typical AI/ML students in India at your current stage:

In AI/ML knowledge and initiative: perhaps around the top 20–30%.
In overall placement readiness (AI + DSA + projects + internships + interview skills): perhaps around the top 35–45%.

To reach the top 10%, you would usually need several of:

Strong DSA (150–300+ quality problems)
PyTorch proficiency
2–3 impressive end-to-end AI projects
Internship or research experience
Strong GitHub portfolio
Good understanding of OS, DBMS, CN, and OOP
Interview practice

The encouraging part is that you're only 20 and still have significant time before final placements. The gap between top 30% and top 10% is often much smaller than people think—it usually comes from consistent execution over the next year or two rather than learning completely new topics.

It means I'm ahead 70  percent of Aiml 2nd year students

Based on the information you've shared, yes, it's reasonable to say you're likely ahead of many second-year AI/ML students, but I would be careful about claiming an exact number like 70%.

Why?

Because there are thousands of AI/ML students, and we don't know:

Their actual project quality
Their DSA level
Their internship experience
Their college environment
Their consistency

What I can say is:

Compared to a typical second-year AI/ML student

You already have:

Python
ML fundamentals
DL fundamentals
Kaggle experience
GitHub projects
Azure certification
Interest in PyTorch, Transformers, RAG, and MLOps

Many second-year students are still learning Python basics or have only completed a few classroom projects.

So being ahead of a majority of second-year AI/ML students is plausible.

But don't optimize for percentile

A better question is:

"Would my current profile get shortlisted for a good AI internship?"

Right now, the answer is:

For some internships: Yes
For highly competitive AI internships: Not yet consistently

The next big improvements for you are:

Strong DSA
PyTorch
End-to-end AI projects (RAG, LLM apps, agents)
Interview preparation
Internship/research experience

If you execute well on those over the next year, you can move from "ahead of many students" to being among the stronger candidates recruiters actively notice.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)

# %%
tokenizer.word_index

# %%
input_sequences=[]
for sentence in faqs.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]
  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])
    print(tokenized_sentence[:i+1])

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape

# %%
y.shape

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=len(tokenizer.word_index)+1)

# %%
y.shape

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(len(tokenizer.word_index)+1, 100))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index)+1, activation='softmax'))

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()

# %%
model.fit(X,y,epochs=100)

# %%
import time
import numpy as np
text = "cv is not equal to "

for i in range(100):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=86, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
