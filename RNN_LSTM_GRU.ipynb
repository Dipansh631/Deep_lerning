# %% [markdown]
# #**RNN Architecture**

# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN

# %%
model=Sequential()
model.add(SimpleRNN(3, input_shape=(4,5)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()

# %%
model.get_weights()[0].shape

# %%
model.get_weights()[0]

# %%
model.get_weights()[1].shape

# %%
model.get_weights()[1]

# %% [markdown]
# #**Encoding**

# %% [markdown]
# ##**Integer Encoding**

# %%
import numpy as np

docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index

# %%
tokenizer.word_counts

# %%
tokenizer.document_count

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences

# %%
from keras.utils import pad_sequences

# %%
sequences=pad_sequences(sequences, padding='post')

# %%
sequences

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train

# %%
X_train.shape

# %%
X_test.shape

# %%
X_train=pad_sequences(X_train,padding='post',maxlen=50)
X_test=pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train

# %%
model = Sequential()

model.add(SimpleRNN(32,input_shape=(50,1),return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.summary()

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))

# %% [markdown]
# ##**Embeddings Encoding**

# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences

# %%
model = Sequential()
model.add(Input(shape=(5,)))
model.add(Embedding(17,output_dim=2))

model.summary()

# %%
pred = model.predict(sequences)
print(pred)

# %%
from keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train.shape

# %%
from keras.layers import Dense, SimpleRNN, Embedding, Flatten, Input # Added Input

model = Sequential()
model.add(Input(shape=(50,)))
model.add(Embedding(10000, 2))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))

# %% [markdown]
# RNN are not used widely so we use LSTM and GRU

# %% [markdown]
# # **RNN UPDATE**

# %% [markdown]
# ## **Deep RNNS**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense,LSTM,GRU

# %%
num_words=10000
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Pad sequences to have the same length
x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %%
model= Sequential([
    Embedding(10000,32,input_length=100),
    SimpleRNN(5,return_sequences=True),
    SimpleRNN(5),
    Dense(1,activation='sigmoid')
])

# %%
model.summary()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')

# %% [markdown]
# ## **Deep LSTM**

# %%
model = Sequential([
    Embedding(10000, 32, input_length=100),
    LSTM(5, return_sequences=True),
    LSTM(5),
    Dense(1, activation='sigmoid')
])

model.summary()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')

# %% [markdown]
# ## **Deep GRU**

# %%
model = Sequential([
    Embedding(10000, 32, input_length=100),
    GRU(5, return_sequences=True),
    GRU(5),
    Dense(1, activation='sigmoid')
])

model.summary()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')

# %%
predictions = model.predict(x_test)
print(predictions[:10])

# %%
import numpy as np

binary_predictions = (predictions > 0.5).astype(int)

print("First 10 binary predictions:")
print(binary_predictions[:10])

# %%
new_test_samples = x_test[:5]

print("New test data shape:", new_test_samples.shape)

new_predictions = model.predict(new_test_samples)

print("\nRaw probabilities for new test data (first 5 samples):")
print(new_predictions)

# %%
new_binary_predictions = (new_predictions > 0.5).astype(int)

print("\nBinary predictions for new test data (first 5 samples):")
print(new_binary_predictions)

# %% [markdown]
# ## **Bidirectional RNNS**

# %%
from keras.layers import Bidirectional # Corrected import
model= Sequential([
    Embedding(10000,32,input_length=100),
    Bidirectional(SimpleRNN(5,return_sequences=True)),
    Bidirectional(SimpleRNN(5)),
    Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %% [markdown]
# ## **Bidirectional LSTM**

# %%
from keras.layers import Bidirectional # Corrected import
model= Sequential([
    Embedding(10000,32,input_length=100),
    Bidirectional(LSTM(5,return_sequences=True)),
    Bidirectional(LSTM(5)),
    Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %%
from keras.layers import Bidirectional # Corrected import
model= Sequential([
    Embedding(10000,32,input_length=100),
    Bidirectional(GRU(5,return_sequences=True)),
    Bidirectional(GRU(5)),
    Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# %% [markdown]
# ## **Bidirectional GRU**

# %%
from keras.layers import Bidirectional # Corrected import
model= Sequential([
    Embedding(10000,32,input_length=100),
    Bidirectional(GRU(5,return_sequences=True)),
    Bidirectional(GRU(5)),
    Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
